# %%
# Importing Dependencies
import pandas as pd
import numpy as np

# %%
# Bringing in Uncleaned CSV's
csv1 = "Data/2014-01 - Citi Bike trip data.csv"
csv2 = "Data/2014-02 - Citi Bike trip data.csv"
bike_trip_2014_1 = pd.read_csv(csv1)
bike_trip_2014_2 = pd.read_csv(csv2)

# %%
# Viewing the 2014_1 Data
bike_2014_1_df = bike_trip_2014_1
bike_2014_1_df.head(2)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           471  2014-01-01 00:00:06  2014-01-01 00:07:57              2009
# 1          1494  2014-01-01 00:00:38  2014-01-01 00:25:32               536
#
#          start station name  start station latitude  start station longitude  \
# 0  Catherine St & Monroe St               40.711174               -73.996826
# 1           1 Ave & E 30 St               40.741444               -73.975361
#
#    end station id          end station name  end station latitude  \
# 0             263  Elizabeth St & Hester St             40.717290
# 1             259   South St & Whitehall St             40.701221
#
#    end station longitude  bikeid    usertype birth year  gender
# 0             -73.996375   16379  Subscriber       1986       1
# 1             -74.012342   15611  Subscriber       1963       1

# %%
# Viewing the 2014_2 Data
bike_2014_2_df = bike_trip_2014_2
bike_2014_2_df.head(2)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           382  2014-02-01 00:00:00  2014-02-01 00:06:22               294
# 1           372  2014-02-01 00:00:03  2014-02-01 00:06:15               285
#
#     start station name  start station latitude  start station longitude  \
# 0  Washington Square E               40.730494               -73.995721
# 1   Broadway & E 14 St               40.734546               -73.990741
#
#    end station id          end station name  end station latitude  \
# 0             265  Stanton St & Chrystie St             40.722293
# 1             439            E 4 St & 2 Ave             40.726281
#
#    end station longitude  bikeid    usertype birth year  gender
# 0             -73.991475   21101  Subscriber       1991       1
# 1             -73.989780   15456  Subscriber       1979       2

# %%
# Deleting Columns
del bike_2014_1_df['usertype']
del bike_2014_2_df['usertype']

# %%
bike_2014_1_df.head(5)
bike_2014_2_df.head(5)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           382  2014-02-01 00:00:00  2014-02-01 00:06:22               294
# 1           372  2014-02-01 00:00:03  2014-02-01 00:06:15               285
# 2           591  2014-02-01 00:00:09  2014-02-01 00:10:00               247
# 3           583  2014-02-01 00:00:32  2014-02-01 00:10:15               357
# 4           223  2014-02-01 00:00:41  2014-02-01 00:04:24               401
#
#         start station name  start station latitude  start station longitude  \
# 0      Washington Square E               40.730494               -73.995721
# 1       Broadway & E 14 St               40.734546               -73.990741
# 2   Perry St & Bleecker St               40.735354               -74.004831
# 3       E 11 St & Broadway               40.732618               -73.991580
# 4  Allen St & Rivington St               40.720196               -73.989978
#
# ...

# %%
# Checking Type of Values
bike_2014_1_df.dtypes
bike_2014_2_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# birth year                  object
# gender                       int64
# dtype: object

# %%
# Changing The Type of Values for the Gender Column for 2014_1
bike_2014_1_df['gender'] = bike_2014_1_df['gender'].astype(str)

# %%
#Changing The Type of Values for the Gender Column for 2014_2
bike_2014_2_df['gender'] = bike_2014_2_df['gender'].astype(str)

# %%
# Changing the Numeric Gender Values to Actual Gender Values For The 2014_1 CSV
gender_check_2014_1 = bike_2014_1_df['gender']
changed_2014_1_male = gender_check_2014_1.replace('1', 'Male')
changed_2014_1_female = changed_2014_1_male.replace('2', 'Female')
changed_2014_1_unknown = changed_2014_1_female.replace('0', 'Unknown')
bike_2014_1_df['gender'] = changed_2014_1_unknown
bike_2014_1_df
# Out:
#         tripduration            starttime             stoptime  \
# 0                471  2014-01-01 00:00:06  2014-01-01 00:07:57
# 1               1494  2014-01-01 00:00:38  2014-01-01 00:25:32
# 2                464  2014-01-01 00:03:59  2014-01-01 00:11:43
# 3                373  2014-01-01 00:05:15  2014-01-01 00:11:28
# 4                660  2014-01-01 00:05:18  2014-01-01 00:16:18
# ...              ...                  ...                  ...
# 300395           780  2014-01-31 23:57:34  2014-02-01 00:10:34
# 300396          1074  2014-01-31 23:57:45  2014-02-01 00:15:39
# 300397           191  2014-01-31 23:58:16  2014-02-01 00:01:27
# 300398          1052  2014-01-31 23:58:34  2014-02-01 00:16:06
# 300399          1133  2014-01-31 23:58:43  2014-02-01 00:17:36
#
#         start station id             start station name  \
# 0                   2009       Catherine St & Monroe St
# 1                    536                1 Ave & E 30 St
# ...

# %%
# Changing the Numeric Gender Values to Actual Gender Values For The 2014_2 CSV
gender_check_2014_2 = bike_2014_2_df['gender']
changed_2014_2_male = gender_check_2014_2.replace('1', 'Male')
changed_2014_2_female = changed_2014_2_male.replace('2', 'Female')
changed_2014_2_unknown = changed_2014_2_female.replace('0', 'Unknown')
bike_2014_2_df['gender'] = changed_2014_2_unknown
bike_2014_2_df
# Out:
#         tripduration            starttime             stoptime  \
# 0                382  2014-02-01 00:00:00  2014-02-01 00:06:22
# 1                372  2014-02-01 00:00:03  2014-02-01 00:06:15
# 2                591  2014-02-01 00:00:09  2014-02-01 00:10:00
# 3                583  2014-02-01 00:00:32  2014-02-01 00:10:15
# 4                223  2014-02-01 00:00:41  2014-02-01 00:04:24
# ...              ...                  ...                  ...
# 224731           848  2014-02-28 23:57:13  2014-03-01 00:11:21
# 224732          1355  2014-02-28 23:57:55  2014-03-01 00:20:30
# 224733           304  2014-02-28 23:58:17  2014-03-01 00:03:21
# 224734           308  2014-02-28 23:59:10  2014-03-01 00:04:18
# 224735           603  2014-02-28 23:59:47  2014-03-01 00:09:50
#
#         start station id            start station name  \
# 0                    294           Washington Square E
# 1                    285            Broadway & E 14 St
# ...

# %%
# Rearranging the Columns
bike_2014_1_df_organized = bike_2014_1_df[["bikeid",
                                       "gender",
                                       "birth year",
                                       "tripduration",
                                       "start station id",
                                       "start station name",
                                       "start station latitude",
                                       "start station longitude",
                                       "starttime",
                                       "end station id",
                                       "end station name", 
                                       "end station latitude",
                                       "end station longitude",
                                       "stoptime"]]

bike_2014_2_df_organized = bike_2014_2_df[["bikeid",
                                       "gender",
                                       "birth year",
                                       "tripduration",
                                       "start station id",
                                       "start station name",
                                       "start station latitude",
                                       "start station longitude",
                                       "starttime",
                                       "end station id",
                                       "end station name", 
                                       "end station latitude",
                                       "end station longitude",
                                       "stoptime"]]

bike_2014_1_df_organized.head(5)
bike_2014_2_df_organized.head(5)
# Out:
#    bikeid  gender birth year  tripduration  start station id  \
# 0   21101    Male       1991           382               294
# 1   15456  Female       1979           372               285
# 2   16281  Female       1948           591               247
# 3   17400    Male       1981           583               357
# 4   19341    Male       1990           223               401
#
#         start station name  start station latitude  start station longitude  \
# 0      Washington Square E               40.730494               -73.995721
# 1       Broadway & E 14 St               40.734546               -73.990741
# 2   Perry St & Bleecker St               40.735354               -74.004831
# 3       E 11 St & Broadway               40.732618               -73.991580
# 4  Allen St & Rivington St               40.720196               -73.989978
#
#              starttime  end station id          end station name  \
# 0  2014-02-01 00:00:00             265  Stanton St & Chrystie St
# ...

# %%
# Renaming the Columns
bike_2014_1_renamed_df = bike_2014_1_df_organized.rename(columns={"bikeid":"Bike ID", 
                                                              "gender":"Gender",
                                                              "birth year":"Birth Year",
                                                              "tripduration":"Trip Duration",
                                                              "start station id":"Start Station ID",
                                                              "start station name":"Start Station Name",
                                                              "start station latitude":"Start Station Latitude",
                                                              "start station longitude":"Start Station Longitude",
                                                              "starttime":"Start Time",
                                                              "end station id":"End Station ID",
                                                              "end station name":"End Station Name",
                                                              "end station latitude":"End Station Latitude",
                                                              "end station longitude":"End Station Longitude",
                                                              "stoptime":"Stop Time"})

bike_2014_2_renamed_df = bike_2014_2_df_organized.rename(columns={"bikeid":"Bike ID", 
                                                              "gender":"Gender",
                                                              "birth year":"Birth Year",
                                                              "tripduration":"Trip Duration",
                                                              "start station id":"Start Station ID",
                                                              "start station name":"Start Station Name",
                                                              "start station latitude":"Start Station Latitude",
                                                              "start station longitude":"Start Station Longitude",
                                                              "starttime":"Start Time",
                                                              "end station id":"End Station ID",
                                                              "end station name":"End Station Name",
                                                              "end station latitude":"End Station Latitude",
                                                              "end station longitude":"End Station Longitude",
                                                              "stoptime":"Stop Time"})



bike_2014_1_renamed_df
bike_2014_2_renamed_df
# Out:
#         Bike ID  Gender Birth Year  Trip Duration  Start Station ID  \
# 0         21101    Male       1991            382               294
# 1         15456  Female       1979            372               285
# 2         16281  Female       1948            591               247
# 3         17400    Male       1981            583               357
# 4         19341    Male       1990            223               401
# ...         ...     ...        ...            ...               ...
# 224731    17413    Male       1976            848               498
# 224732    15608  Female       1985           1355               470
# 224733    17112    Male       1968            304               497
# 224734    14761    Male       1982            308               353
# 224735    18783    Male       1960            603               252
#
#                   Start Station Name  Start Station Latitude  \
# 0                Washington Square E               40.730494
# ...
